# %% [markdown]
# <a href="https://colab.research.google.com/github/Yagami360/MachineLearning_Exercises_Python_PyTorch/blob/master/GAN_WGAN_PyTorch/WGAN_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Google Colab 用の Jupiter Notebook

# %%
# -*- coding:utf-8 -*-

"""
    更新情報
    [19/04/23] : 新規作成
    [xx/xx/xx] : 
               : 
"""
import os
import numpy as np
from tqdm import tqdm

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.utils import save_image


class Generator( nn.Module ):
    """
    WGAN の生成器 G [Generator] 側のネットワーク構成を記述したモデル。

    [public]
    [protected] 変数名の前にアンダースコア _ を付ける
        _device : <toech.cuda.device> 使用デバイス
        _layer : <nn.Sequential> 生成器のネットワーク構成
    [private] 変数名の前にダブルアンダースコア __ を付ける（Pythonルール）

    """
    def __init__(
        self,
        device,
        n_input_noize_z = 100,
        n_channels = 3,
        n_fmaps = 64
    ):
        super( Generator, self ).__init__()
        self._device = device
        
        self._layer = nn.Sequential(
            nn.ConvTranspose2d(n_input_noize_z, n_fmaps*8, kernel_size=4, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(n_fmaps*8),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d( n_fmaps*8, n_fmaps*4, kernel_size=4, stride=2, padding=1, bias=False ),
            nn.BatchNorm2d(n_fmaps*4),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d( n_fmaps*4, n_fmaps*2, kernel_size=4, stride=2, padding=1, bias=False ),
            nn.BatchNorm2d(n_fmaps*2),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d( n_fmaps*2, n_fmaps, kernel_size=4, stride=2, padding=1, bias=False ),
            nn.BatchNorm2d(n_fmaps),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d( n_fmaps, n_channels, kernel_size=4, stride=2, padding=1, bias=False ),
            nn.Tanh()
        ).to( self._device )

        self.init_weight()
        return

    def init_weight( self ):
        """
        独自の重みの初期化処理
        """
        return

    def forward( self, input ):
        """
        ネットワークの順方向での更新処理
        ・nn.Module クラスのメソッドをオーバライト

        [Args]
            input : <Tensor> ネットワークに入力されるデータ（ノイズデータ等）
        [Returns]
            output : <Tensor> ネットワークからのテンソルの出力
        """
        output = self._layer(input)
        return output


class Critic( nn.Module ):
    """
    WGAN のクリティック側のネットワーク構成を記述したモデル。

    [public]
    [protected] 変数名の前にアンダースコア _ を付ける
        _device : <toech.cuda.device> 使用デバイス
        _layer : <nn.Sequential> クリティックのネットワーク構成
    [private] 変数名の前にダブルアンダースコア __ を付ける（Pythonルール）
    """
    def __init__(
       self,
       device,
       n_channels = 3,
       n_fmaps = 64
    ):
        super( Critic, self ).__init__()
        self._device = device
        
        self._layer = nn.Sequential(
            nn.Conv2d(n_channels, n_fmaps, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(n_fmaps, n_fmaps*2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(n_fmaps*2),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(n_fmaps*2, n_fmaps*4, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(n_fmaps*4),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(n_fmaps*4, n_fmaps*8, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(n_fmaps*8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(n_fmaps*8, 1, kernel_size=4, stride=1, padding=0, bias=False),
        ).to( self._device )

        self.init_weight()

        return

    def init_weight( self ):
        """
        独自の重みの初期化処理
        """
        return

    def forward(self, input):
        # input : torch.Size([batch_size, n_channels, width, height])
        output = self._layer( input )

        # ミニバッチ平均
        output = output.mean(0)

        return output.view(1)


class WassersteinGAN( object ):
    """
    WGAN [Wasserstein GAN] を表すクラス
    --------------------------------------------
    [public]

    [protected] 変数名の前にアンダースコア _ を付ける
        _device : <toech.cuda.device> 実行デバイス

        _n_epoches : <int> エポック数（学習回数）
        _learnig_rate : <float> 最適化アルゴリズムの学習率
        _batch_size : <int> ミニバッチ学習時のバッチサイズ
        _n_channels : <int> 入力画像のチャンネル数
        _n_fmaps : <int> 特徴マップの枚数
        _n_input_noize_z : <int> 入力ノイズ z の次元数

        _n_critic : <int> クリティックの更新回数
        _w_clamp_lower : <float> 重みクリッピングの下限値
        _w_clamp_upper : <float> 重みクリッピングの上限値

        _generator : <nn.Module> DCGAN の生成器
        _critic : <nn.Module> DCGAN のクリティック

        _loss_fn : <> 損失関数

        _G_optimizer : <torch.optim.Optimizer> 生成器の最適化アルゴリズム
        _C_optimizer : <torch.optim.Optimizer> クリティックの最適化アルゴリズム

        _loss_G_historys : <list> 生成器 G の損失関数値の履歴（イテレーション毎）
        _loss_C_historys : <list> クリティック C の損失関数値の履歴（イテレーション毎）

        _images_historys : <list> 生成画像のリスト

        _f_historys : <list> クリティックからの出力（リプシッツ連続な関数 f）

    [private] 変数名の前にダブルアンダースコア __ を付ける（Pythonルール）

    """
    def __init__(
        self,
        device,
        n_epoches = 300,
        learing_rate = 0.0001,
        batch_size = 64,
        n_channels = 3,
        n_fmaps = 64,
        n_input_noize_z = 100,
        n_critic = 5,
        w_clamp_lower = - 0.01,
        w_clamp_upper = 0.01
    ):
        self._device = device

        self._n_epoches = n_epoches
        self._learning_rate = learing_rate
        self._batch_size = batch_size
        self._n_channels = n_channels
        self._n_fmaps = n_fmaps
        self._n_input_noize_z = n_input_noize_z

        self._n_critic = n_critic
        self._w_clamp_lower = w_clamp_lower
        self._w_clamp_upper = w_clamp_upper

        self._generator = None
        self._critic = None
        self._loss_fn = None
        self._G_optimizer = None
        self._C_optimizer = None
        self._loss_G_historys = []
        self._loss_C_historys = []
        self._images_historys = []

        self.model()
        self.loss()
        self.optimizer()
        return

    def print( self, str = "" ):
        print( "----------------------------------" )
        print( "WassersteinGAN" )
        print( self )
        print( str )
        print( "_device :", self._device )
        print( "_n_epoches :", self._n_epoches )
        print( "_learning_rate :", self._learning_rate )
        print( "_batch_size :", self._batch_size )
        print( "_n_channels :", self._n_channels )
        print( "_n_fmaps :", self._n_fmaps )
        print( "_n_input_noize_z :", self._n_input_noize_z )
        print( "_n_critic :", self._n_critic )
        print( "_w_clamp_lower :", self._w_clamp_lower )
        print( "_w_clamp_upper :", self._w_clamp_upper )
        print( "_generator :", self._generator )
        print( "_critic :", self._critic )
        print( "_loss_fn :", self._loss_fn )
        print( "_G_optimizer :", self._G_optimizer )
        print( "_C_optimizer :", self._C_optimizer )
        print( "----------------------------------" )
        return


    @property
    def device( self ):
        """ device の Getter """
        return self._device

    @device.setter
    def device( self, device ):
        """ device の Setter """
        self._device = device
        return

    @property
    def loss_G_history( self ):
        return self._loss_G_historys

    @property
    def loss_C_history( self ):
        return self._loss_C_historys

    @property
    def images_historys( self ):
        return self._images_historys


    def model( self ):
        """
        モデルの定義を行う。

        [Args]
        [Returns]
        """
        self._generator = Generator( 
            self._device, 
            n_input_noize_z = self._n_input_noize_z,
            n_channels = self._n_channels,
            n_fmaps = self._n_fmaps
        )

        self._critic = Critic( 
            self._device,
            n_channels = self._n_channels,
            n_fmaps = self._n_fmaps
        )

        return

    def loss( self ):
        """
        損失関数の設定を行う。
        [Args]
        [Returns]
        """
        # Binary Cross Entropy
        # L(x,y) = - { y*log(x) + (1-y)*log(1-x) }
        # x,y の設定は、後の fit() 内で行う。
        #self._loss_fn = nn.BCELoss()

        return

    def optimizer( self ):
        """
        モデルの最適化アルゴリズムの設定を行う。
        [Args]
        [Returns]
        """
        # GeneratorとDiscriminatorはそれぞれ別のOptimizerがある
        # PyTorchはOptimizerの更新対象となるパラメータを第1引数で指定することになっている（TensorFlowやKerasにはなかった）
        # この機能のおかげで D_optimizer.step() でパラメータ更新を走らせたときに、
        # Discriminatorのパラメータしか更新されず、Generatorのパラメータは固定される。
        # これにより TensorFlow における、
        # tf.control_dependencies(...) : sess.run で実行する際のトレーニングステップの依存関係（順序）を定義
        # に対応する処理が簡単にわかりやすく行える。
        """
        self._G_optimizer = optim.Adam(
            params = self._generator.parameters(),
            lr = self._learning_rate,
            betas = (0.5,0.999)
        )
        """
        self._G_optimizer = optim.RMSprop(
            params = self._generator.parameters(),
            lr = self._learning_rate
        )

        """
        self._C_optimizer = optim.Adam(
            params = self._critic.parameters(),
            lr = self._learning_rate,
            betas = (0.5,0.999)
        )
        """
        self._C_optimizer = optim.RMSprop(
            params = self._critic.parameters(),
            lr = self._learning_rate
        )
        return


    def fit( self, dloader, n_sava_step = 5 ):
        """
        指定されたトレーニングデータで、モデルの fitting 処理を行う。
        [Args]
            dloader : <DataLoader> 学習用データセットの DataLoader
            n_sava_step : <int> 学習途中での生成画像の保存間隔（エポック単位）
        [Returns]
        """
        # 1 と -1 の Tensor : 誤差逆伝搬の基準に使用する。
        one_tsr =  torch.FloatTensor([1]).to( self._device )
        mone_tsr = one_tsr * -1

        # 入力ノイズ z
        input_noize_z = torch.FloatTensor( self._batch_size, self._n_input_noize_z ).to( self._device )

        #-------------------------------------
        # モデルを学習モードに切り替える。
        #-------------------------------------
        self._generator.train()
        self._critic.train()

        #-------------------------------------
        # 学習処理ループ
        #-------------------------------------
        iterations = 0      # 学習処理のイテレーション回数

        print("Starting Training Loop...")
        # エポック数分トレーニング
        for epoch in tqdm( range(self._n_epoches), desc = "Epoches" ):
            # DataLoader から 1minibatch 分取り出し、ミニバッチ処理
            for (images,targets) in tqdm( dloader, desc = "minbatch process in DataLoader" ):
                #print( "images.size() : ", images.size() )
                #print( "targets.size() : ", targets.size() )

                # 一番最後のミニバッチループで、バッチサイズに満たない場合は無視する
                # （後の計算で、shape の不一致をおこすため）
                if images.size()[0] != self._batch_size:
                    break

                iterations += 1

                # ミニバッチデータを GPU へ転送
                images = images.to( self._device )

                #====================================================
                # クリティック C の fitting 処理
                #====================================================
                # 無効化していたクリティック C のネットワークの勾配計算を有効化。
                for param in self._critic.parameters():
                    param.requires_grad = True

                for n in range( self._n_critic ):
                    #----------------------------------------------------
                    # 重みクリッピング
                    #----------------------------------------------------
                    for param in self._critic.parameters():
                        #print( "critic param :", param )
                        param.data.clamp_( self._w_clamp_lower, self._w_clamp_upper )
                        #print( "critic param :", param )

                    # 生成器 G に入力するノイズ z
                    # Generatorの更新の前にノイズを新しく生成しなおす必要があり。
                    input_noize_z.resize_( self._batch_size, self._n_input_noize_z, 1 , 1 ).normal_(0, 1)

                    #----------------------------------------------------
                    # 勾配を 0 に初期化
                    # （この初期化処理が必要なのは、勾配がイテレーション毎に加算される仕様のため）
                    #----------------------------------------------------
                    self._C_optimizer.zero_grad()

                    #----------------------------------------------------
                    # 学習用データをモデルに流し込む
                    # model(引数) で呼び出せるのは、__call__ をオーバライトしているため
                    #----------------------------------------------------
                    # E[C(x)] : 本物画像 x = image を入力したときのクリティックの出力 （平均化処理済み）
                    C_x = self._critic( images )
                    #print( "C_x.size() :", C_x.size() )
                    #print( "C_x :", C_x )

                    # 微分を行わない処理の範囲を with 構文で囲む
                    # クリティック D の学習中は、生成器 G のネットワークの勾配は更新しない。
                    with torch.no_grad():
                        # G(z) : 生成器から出力される偽物画像
                        G_z = self._generator( input_noize_z )
                        #print( "G_z.size() :", G_z.size() )     # torch.Size([128, 1, 28, 28])
                        #print( "G_z :", G_z )

                    # E[ C( G(z) ) ] : 偽物画像を入力したときの識別器の出力 (平均化処理済み)
                    C_G_z = self._critic( G_z )
                    #print( "C_G_z.size() :", C_G_z.size() )
                    #print( "C_G_z :", C_G_z )

                    #----------------------------------------------------
                    # 損失関数を計算する
                    # 出力と教師データを損失関数に設定し、誤差 loss を計算
                    # この設定は、損失関数を __call__ をオーバライト
                    # loss は Pytorch の Variable として帰ってくるので、これをloss.data[0]で数値として見る必要があり
                    #----------------------------------------------------
                    # E_x[ C(x) ]
                    #loss_C_real = torch.mean( C_x )
                    loss_C_real = C_x
                    #print( "loss_C_real : ", loss_C_real.item() )

                    # E_z[ C(G(z) ]
                    #loss_C_fake = torch.mean( C_G_z )
                    loss_C_fake = C_G_z
                    #print( "loss_C_fake : ", loss_C_fake.item() )

                    # クリティック C の損失関数 = E_x[ C(x) ] + E_z[ C(G(z) ]
                    loss_C = loss_C_real - loss_C_fake
                    #print( "loss_C : ", loss_C.item() )

                    #----------------------------------------------------
                    # 誤差逆伝搬
                    #----------------------------------------------------
                    loss_C_real.backward( one_tsr )
                    loss_C_fake.backward( mone_tsr )
                    #loss_C.backward()

                    #----------------------------------------------------
                    # backward() で計算した勾配を元に、設定した optimizer に従って、重みを更新
                    #----------------------------------------------------
                    self._C_optimizer.step()

                #====================================================
                # 生成器 G の fitting 処理
                #====================================================
                # クリティック C のネットワークの勾配計算を行わないようにする。
                for param in self._critic.parameters():
                    param.requires_grad = False

                # 生成器 G に入力するノイズ z
                # Generatorの更新の前にノイズを新しく生成しなおす必要があり。
                input_noize_z.resize_( self._batch_size, self._n_input_noize_z, 1, 1 ).normal_(0, 1)

                #----------------------------------------------------
                # 勾配を 0 に初期化
                # （この初期化処理が必要なのは、勾配がイテレーション毎に加算される仕様のため）
                #----------------------------------------------------
                self._G_optimizer.zero_grad()

                #----------------------------------------------------
                # 学習用データをモデルに流し込む
                # model(引数) で呼び出せるのは、__call__ をオーバライトしているため
                #----------------------------------------------------
                # G(z) : 生成器から出力される偽物画像
                G_z = self._generator( input_noize_z )
                #print( "G_z.size() :", G_z.size() )
                #print( "G_z :", G_z )

                # E[C( G(z) )] : 偽物画像を入力したときのクリティックの出力（平均化処理済み）
                C_G_z = self._critic( G_z )
                #print( "C_G_z.size() :", C_G_z.size() )

                #----------------------------------------------------
                # 損失関数を計算する
                #----------------------------------------------------
                # L_G = E_z[ C(G(z) ]
                #loss_G = torch.mean( C_G_z )
                loss_G = C_G_z
                #print( "loss_G :", loss_G )

                #----------------------------------------------------
                # 誤差逆伝搬
                #----------------------------------------------------
                #loss_G.backward()
                loss_G.backward( one_tsr )

                #----------------------------------------------------
                # backward() で計算した勾配を元に、設定した optimizer に従って、重みを更新
                #----------------------------------------------------
                self._G_optimizer.step()

                #
                self._loss_C_historys.append( loss_C.item() )
                self._loss_G_historys.append( loss_G.item() )

            #----------------------------------------------------
            # 学習過程での自動生成画像
            #----------------------------------------------------
            # 特定のエポックでGeneratorから画像を保存
            if( epoch % n_sava_step == 0 ):
                images = self.generate_images( n_samples = 64, b_transformed = False )
                self._images_historys.append( images )

                save_image( 
                    tensor = images, 
                    filename = "WGAN_Image_epoches{}_iters{}.png".format( epoch, iterations )
                )

        print("Finished Training Loop.")
        return


    def generate_images( self, n_samples = 64, b_transformed = False ):
        """
        DCGAN の Generator から、画像データを自動生成する。
        [Input]
            n_samples : <int> 生成する画像の枚数
            b_transformed : <bool> 画像のフォーマットを Tensor から変換するか否か
        [Output]
            images : <Tensor> / shape = [n_samples, n_channels, height, width]
                生成された画像データのリスト
                行成分は生成する画像の数 n_samples
        """
        # 生成器を推論モードに切り替える。
        self._generator.eval()

        # 生成のもとになる乱数を生成
        input_noize_z = torch.rand( (n_samples, self._n_input_noize_z, 1, 1) ).to( self._device )

        # 画像を生成
        images = self._generator( input_noize_z )
        #print( "images.size() :", images.size() )   # torch.Size([64, 1, 28, 28])

        if( b_transformed == True ):
            # Tensor → numpy に変換
            images = images.cpu().detach().numpy()

        return images

# %%
# -*- coding:utf-8 -*-

from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
#import pickle
import scipy.misc

# PyTorch
import torch
from torch.utils.data import TensorDataset, DataLoader

import torchvision      # 画像処理関連
import torchvision.transforms as transforms
from torchvision.utils import save_image


#--------------------------------
# 設定可能な定数
#--------------------------------
#DEVICE = "CPU"               # 使用デバイス ("CPU" or "GPU")
DEVICE = "GPU"                # 使用デバイス ("CPU" or "GPU")
DATASET = "MNIST"            # データセットの種類（"MNIST" or "CIFAR-10"）
#DATASET = "CIFAR-10"          # データセットの種類（"MNIST" or "CIFAR-10"）
DATASET_PATH = "./dataset"    # 学習用データセットへのパス
NUM_SAVE_STEP = 1             # 自動生成画像の保存間隔（エポック単位）

NUM_EPOCHES = 10               # エポック数（学習回数）
LEARNING_RATE = 0.00005       # 学習率 (Default:0.00005)
BATCH_SIZE = 64               # ミニバッチサイズ
IMAGE_SIZE = 64               # 入力画像のサイズ（pixel単位）
NUM_CHANNELS = 1              # 入力画像のチャンネル数
NUM_FEATURE_MAPS = 64         # 特徴マップの枚数
NUM_INPUT_NOIZE_Z = 100       # 生成器に入力するノイズ z の次数
NUM_CRITIC = 5                # クリティックの更新回数
WEIGHT_CLAMP_LOWER = - 0.01   # 重みクリッピングの下限値
WEIGHT_CLAMP_UPPER = 0.01     # 重みクリッピングの上限値


def main():
    """
    Wasserstein による画像の自動生成
    ・学習用データセットは、MNIST / CIFAR-10
    """
    print("Start main()")
    
    # バージョン確認
    print( "PyTorch :", torch.__version__ )

    # 実行条件の出力
    print( "----------------------------------------------" )
    print( "実行条件" )
    print( "----------------------------------------------" )
    print( "開始時間：", datetime.now() )
    print( "DEVICE : ", DEVICE )
    print( "NUM_EPOCHES : ", NUM_EPOCHES )
    print( "LEARNING_RATE : ", LEARNING_RATE )
    print( "BATCH_SIZE : ", BATCH_SIZE )
    print( "IMAGE_SIZE : ", IMAGE_SIZE )
    print( "NUM_CHANNELS : ", NUM_CHANNELS )
    print( "NUM_FEATURE_MAPS : ", NUM_FEATURE_MAPS )
    print( "NUM_INPUT_NOIZE_Z : ", NUM_INPUT_NOIZE_Z )
    print( "NUM_CRITIC : ", NUM_CRITIC )
    print( "WEIGHT_CLAMP_LOWER : ", WEIGHT_CLAMP_LOWER )
    print( "WEIGHT_CLAMP_UPPER : ", WEIGHT_CLAMP_UPPER )

    #===================================
    # 実行 Device の設定
    #===================================
    if( DEVICE == "GPU" ):
        use_cuda = torch.cuda.is_available()
        if( use_cuda == True ):
            device = torch.device( "cuda" )
            print( "実行デバイス :", device)
            print( "GPU名 :", torch.cuda.get_device_name(0))
            print("torch.cuda.current_device() =", torch.cuda.current_device())
        else:
            print( "can't using gpu." )
            device = torch.device( "cpu" )
            print( "実行デバイス :", device)
    else:
        device = torch.device( "cpu" )
        print( "実行デバイス :", device)

    print( "----------------------------------------------" )

    # seed 値の固定
    import random
    random.seed(8)
    np.random.seed(8)
    torch.manual_seed(8)

    #======================================================================
    # データセットを読み込み or 生成
    # データの前処理
    #======================================================================
    dataset = DATASET

    # データをロードした後に行う各種前処理の関数を構成を指定する。
    if( dataset == "MNIST" ):
        """
        transform = transforms.Compose(
            [
                transforms.ToTensor(),   # Tensor に変換]
            ]
        """
        transform = transforms.Compose(
            [
                transforms.Scale(IMAGE_SIZE),
                transforms.ToTensor(),   # Tensor に変換]
                transforms.Normalize((0.5,), (0.5,)),   # 1 channel 分
            ]
        )
    elif( dataset == "CIFAR-10" ):
        transform = transforms.Compose(
            [
                transforms.Scale(IMAGE_SIZE),
                transforms.ToTensor(),   # Tensor に変換
                transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
            ]
        )
    else:
        print( "Warning: Invalid dataset" )

    #---------------------------------------------------------------
    # data と label をセットにした TensorDataSet の作成
    #---------------------------------------------------------------
    if( dataset == "MNIST" ):
        ds_train = torchvision.datasets.MNIST(
            root = DATASET_PATH,
            train = True,
            transform = transform,      # transforms.Compose(...) で作った前処理の一連の流れ
            target_transform = None,    
            download = True,
        )

        ds_test = torchvision.datasets.MNIST(
            root = DATASET_PATH,
            train = False,
            transform = transform,
            target_transform = None,
            download = True
        )
    elif( dataset == "CIFAR-10" ):
        ds_train = torchvision.datasets.CIFAR10(
            root = DATASET_PATH,
            train = True,
            transform = transform,      # transforms.Compose(...) で作った前処理の一連の流れ
            target_transform = None,    
            download = True
        )

        ds_test = torchvision.datasets.CIFAR10(
            root = DATASET_PATH,
            train = False,
            transform = transform,
            target_transform = None,
            download = True
        )
    else:
        print( "WARNING: Inavlid dataset" )

    print( "ds_train :", ds_train ) # MNIST : torch.Size([60000, 28, 28]) , CIFAR-10 : (50000, 32, 32, 3)
    print( "ds_test :", ds_test )

    #---------------------------------------------------------------
    # TensorDataset → DataLoader への変換
    # DataLoader に変換することで、バッチ処理が行える。
    # DataLoader クラスは、dataset と sampler クラスを持つ。
    # sampler クラスには、ランダムサンプリングや重点サンプリングなどがある
    #---------------------------------------------------------------
    dloader_train = DataLoader(
        dataset = ds_train,
        batch_size = BATCH_SIZE,
        shuffle = True
    )

    dloader_test = DataLoader(
        dataset = ds_test,
        batch_size = BATCH_SIZE,
        shuffle = False
    )
    
    # [MNIST]
    # Number of datapoints: 60000
    # dloader_train.datset
    # dloader_train.sampler = <RandomSampler, len() = 60000>
    print( "dloader_train :", dloader_train )
    print( "dloader_test :", dloader_test )
    
    #======================================================================
    # モデルの構造を定義する。
    #======================================================================
    if( dataset == "MNIST" ):
        """
        model = WassersteinGANforMNIST(
            device = device,
            n_epoches = NUM_EPOCHES,
            learing_rate = LEARNING_RATE,
            batch_size = BATCH_SIZE,
            n_input_noize_z = NUM_INPUT_NOIZE_Z,
            n_critic = NUM_CRITIC,
            w_clamp_lower = WEIGHT_CLAMP_LOWER,
            w_clamp_upper = WEIGHT_CLAMP_UPPER
        )
        """
        model = WassersteinGAN(
            device = device,
            n_epoches = NUM_EPOCHES,
            learing_rate = LEARNING_RATE,
            batch_size = BATCH_SIZE,
            n_channels = NUM_CHANNELS,
            n_fmaps = NUM_FEATURE_MAPS,
            n_input_noize_z = NUM_INPUT_NOIZE_Z,
            n_critic = NUM_CRITIC,
            w_clamp_lower = WEIGHT_CLAMP_LOWER,
            w_clamp_upper = WEIGHT_CLAMP_UPPER
        )

    else:
        model = WassersteinGAN(
            device = device,
            n_epoches = NUM_EPOCHES,
            learing_rate = LEARNING_RATE,
            batch_size = BATCH_SIZE,
            n_channels = NUM_CHANNELS,
            n_fmaps = NUM_FEATURE_MAPS,
            n_input_noize_z = NUM_INPUT_NOIZE_Z,
            n_critic = NUM_CRITIC,
            w_clamp_lower = WEIGHT_CLAMP_LOWER,
            w_clamp_upper = WEIGHT_CLAMP_UPPER
        )

    model.print( "after init()" )

    #print( "model.device() :", model.device )

    #---------------------------------------------------------------
    # 損失関数を設定
    #---------------------------------------------------------------
    #model.loss()

    #---------------------------------------------------------------
    # optimizer を設定
    #---------------------------------------------------------------
    #model.optimizer()

    #======================================================================
    # モデルの学習フェイズ
    #======================================================================
    model.fit( dloader = dloader_train, n_sava_step = NUM_SAVE_STEP )

    #===================================
    # 学習結果の描写処理
    #===================================
    #-----------------------------------
    # 損失関数の plot
    #-----------------------------------
    plt.clf()
    plt.plot(
        range( 0, len(model.loss_G_history) ), model.loss_G_history,
        label = "loss : Generator",
        linestyle = '-',
        linewidth = 0.2,
        color = 'red'
    )
    plt.plot(
        range( 0, len(model.loss_C_history) ), model.loss_C_history,
        label = "loss : Critic",
        linestyle = '-',
        linewidth = 0.2,
        color = 'blue'
    )
    plt.title( "loss" )
    plt.legend( loc = 'best' )
    #plt.xlim( 0, len(model.loss_G_history) )
    #plt.ylim( [0, 1.05] )
    plt.xlabel( "iterations" )
    plt.grid()
    plt.tight_layout()
    plt.savefig(
        "WGAN_Loss_epoches{}_lr{}_batchsize{}.png".format( NUM_EPOCHES, LEARNING_RATE, BATCH_SIZE ),  
        dpi = 300, bbox_inches = "tight"
    )
    plt.show()

    #-------------------------------------------------------------------
    # 学習済み DCGAN に対し、自動生成画像を表示
    #-------------------------------------------------------------------
    images = model.generate_images( n_samples = 64, b_transformed = False )
    #print( "images.size() : ", images.size() )    # (64, 1, 28, 28)

    save_image( 
        tensor = images, 
        filename = "WGAN_Image_epoches{}_lr{}_batchsize{}.png".format( NUM_EPOCHES, LEARNING_RATE, BATCH_SIZE )
    )

    """
    images = model.generate_images( n_samples = 64, b_transformed = True )
    scipy.misc.imsave( 
        "DCGAN_Image_epoches{}_lr{}_batchsize{}.png".format( NUM_EPOCHES, LEARNING_RATE, BATCH_SIZE ),
        np.vstack(
            np.array( [ np.hstack(img) for img in images ] )
        )
    )
    """

    print("Finish main()")
    print( "終了時間：", datetime.now() )

    return


    
if __name__ == '__main__':
     main()
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:208: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")
# 0it [00:00, ?it/s]
# Start main()
# PyTorch : 1.0.1.post2
# ----------------------------------------------
# 実行条件
# ----------------------------------------------
# 開始時間： 2019-04-24 12:59:12.475658
# DEVICE :  GPU
# NUM_EPOCHES :  10
# LEARNING_RATE :  5e-05
# BATCH_SIZE :  64
# IMAGE_SIZE :  64
# NUM_CHANNELS :  1
# NUM_FEATURE_MAPS :  64
# NUM_INPUT_NOIZE_Z :  100
# NUM_CRITIC :  5
# WEIGHT_CLAMP_LOWER :  -0.01
# WEIGHT_CLAMP_UPPER :  0.01
# 実行デバイス : cuda
# GPU名 : Tesla T4
# torch.cuda.current_device() = 0
# ----------------------------------------------
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:00, 20189476.62it/s]
# Extracting ./dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 32768it [00:00, 311744.15it/s]
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# Extracting ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:00, 5648471.89it/s]
# 8192it [00:00, 126928.28it/s]
# Extracting ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# ds_train : Dataset MNIST
#     Number of datapoints: 60000
#     Split: train
#     Root Location: ./dataset
#     Transforms (if any): Compose(
#                              Scale(size=64, interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.5,), std=(0.5,))
#                          )
#     Target Transforms (if any): None
# ds_test : Dataset MNIST
#     Number of datapoints: 10000
#     Split: test
#     Root Location: ./dataset
#     Transforms (if any): Compose(
#                              Scale(size=64, interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.5,), std=(0.5,))
#                          )
#     Target Transforms (if any): None
# dloader_train : <torch.utils.data.dataloader.DataLoader object at 0x7f6054eb3e48>
# dloader_test : <torch.utils.data.dataloader.DataLoader object at 0x7f6054edf160>
# Epoches:   0%|          | 0/10 [00:00<?, ?it/s]
# minbatch process in DataLoader:   0%|          | 0/938 [00:00<?, ?it/s]
# ----------------------------------
# WassersteinGAN
# <__main__.WassersteinGAN object at 0x7f6054edf240>
# after init()
# _device : cuda
# _n_epoches : 10
# _learning_rate : 5e-05
# _batch_size : 64
# _n_channels : 1
# _n_fmaps : 64
# _n_input_noize_z : 100
# _n_critic : 5
# _w_clamp_lower : -0.01
# _w_clamp_upper : 0.01
# _generator : Generator(
#   (_layer): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace)
#     (12): ConvTranspose2d(64, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )
# _critic : Critic(
#   (_layer): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   )
# )
# _loss_fn : None
# _G_optimizer : RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 5e-05
#     momentum: 0
#     weight_decay: 0
# )
# _C_optimizer : RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 5e-05
#     momentum: 0
#     weight_decay: 0
# )
# ----------------------------------
# Starting Training Loop...
# minbatch process in DataLoader:   0%|          | 1/938 [00:00<07:18,  2.14it/s]
# minbatch process in DataLoader:   0%|          | 2/938 [00:00<06:44,  2.31it/s]
# minbatch process in DataLoader:   0%|          | 3/938 [00:01<06:24,  2.43it/s]
# minbatch process in DataLoader:   0%|          | 4/938 [00:01<06:07,  2.54it/s]
# minbatch process in DataLoader:   1%|          | 5/938 [00:01<05:59,  2.60it/s]
# minbatch process in DataLoader:   1%|          | 6/938 [00:02<05:49,  2.67it/s]
# minbatch process in DataLoader:   1%|          | 7/938 [00:02<05:46,  2.69it/s]
# minbatch process in DataLoader:   1%|          | 8/938 [00:02<05:43,  2.71it/s]
# minbatch process in DataLoader:   1%|          | 9/938 [00:03<05:41,  2.72it/s]
# minbatch process in DataLoader:   1%|          | 10/938 [00:03<05:41,  2.72it/s]
# minbatch process in DataLoader:   1%|          | 11/938 [00:04<05:36,  2.75it/s]
# minbatch process in DataLoader:   1%|▏         | 12/938 [00:04<05:37,  2.74it/s]
# minbatch process in DataLoader:   1%|▏         | 13/938 [00:04<05:37,  2.74it/s]
# minbatch process in DataLoader:   1%|▏         | 14/938 [00:05<05:38,  2.73it/s]
# minbatch process in DataLoader:   2%|▏         | 15/938 [00:05<05:38,  2.73it/s]
# minbatch process in DataLoader:   2%|▏         | 16/938 [00:05<05:37,  2.73it/s]
# minbatch process in DataLoader:   2%|▏         | 17/938 [00:06<05:37,  2.73it/s]
# minbatch process in DataLoader:   2%|▏         | 18/938 [00:06<05:37,  2.72it/s]
# minbatch process in DataLoader:   2%|▏         | 19/938 [00:06<05:37,  2.73it/s]
# minbatch process in DataLoader:   2%|▏         | 20/938 [00:07<05:37,  2.72it/s]
# minbatch process in DataLoader:   2%|▏         | 21/938 [00:07<05:37,  2.72it/s]
# minbatch process in DataLoader:   2%|▏         | 22/938 [00:08<05:36,  2.72it/s]
# minbatch process in DataLoader:   2%|▏         | 23/938 [00:08<05:36,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 24/938 [00:08<05:35,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 25/938 [00:09<05:35,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 26/938 [00:09<05:34,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 27/938 [00:09<05:34,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 28/938 [00:10<05:34,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 29/938 [00:10<05:34,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 30/938 [00:11<05:34,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 31/938 [00:11<05:33,  2.72it/s]
# minbatch process in DataLoader:   3%|▎         | 32/938 [00:11<05:33,  2.72it/s]
# minbatch process in DataLoader:   4%|▎         | 33/938 [00:12<05:33,  2.72it/s]
# minbatch process in DataLoader:   4%|▎         | 34/938 [00:12<05:32,  2.72it/s]
# minbatch process in DataLoader:   4%|▎         | 35/938 [00:12<05:32,  2.72it/s]
# minbatch process in DataLoader:   4%|▍         | 36/938 [00:13<05:32,  2.71it/s]
# minbatch process in DataLoader:   4%|▍         | 37/938 [00:13<05:32,  2.71it/s]
# minbatch process in DataLoader:   4%|▍         | 38/938 [00:13<05:31,  2.71it/s]
# minbatch process in DataLoader:   4%|▍         | 39/938 [00:14<05:31,  2.72it/s]
# minbatch process in DataLoader:   4%|▍         | 40/938 [00:14<05:30,  2.72it/s]
# minbatch process in DataLoader:   4%|▍         | 41/938 [00:15<05:31,  2.71it/s]
# minbatch process in DataLoader:   4%|▍         | 42/938 [00:15<05:30,  2.71it/s]
# minbatch process in DataLoader:   5%|▍         | 43/938 [00:15<05:29,  2.71it/s]
# minbatch process in DataLoader:   5%|▍         | 44/938 [00:16<05:29,  2.72it/s]
# minbatch process in DataLoader:   5%|▍         | 45/938 [00:16<05:29,  2.71it/s]
# minbatch process in DataLoader:   5%|▍         | 46/938 [00:16<05:28,  2.72it/s]
# minbatch process in DataLoader:   5%|▌         | 47/938 [00:17<05:27,  2.72it/s]
# minbatch process in DataLoader:   5%|▌         | 48/938 [00:17<05:27,  2.72it/s]
# minbatch process in DataLoader:   5%|▌         | 49/938 [00:18<05:27,  2.72it/s]
# minbatch process in DataLoader:   5%|▌         | 50/938 [00:18<05:26,  2.72it/s]
# minbatch process in DataLoader:   5%|▌         | 51/938 [00:18<05:26,  2.71it/s]
# minbatch process in DataLoader:   6%|▌         | 52/938 [00:19<05:26,  2.72it/s]
# minbatch process in DataLoader:   6%|▌         | 53/938 [00:19<05:25,  2.72it/s]
# minbatch process in DataLoader:   6%|▌         | 54/938 [00:19<05:25,  2.71it/s]
# minbatch process in DataLoader:   6%|▌         | 55/938 [00:20<05:25,  2.72it/s]
# minbatch process in DataLoader:   6%|▌         | 56/938 [00:20<05:24,  2.72it/s]
# minbatch process in DataLoader:   6%|▌         | 57/938 [00:20<05:24,  2.71it/s]
# minbatch process in DataLoader:   6%|▌         | 58/938 [00:21<05:24,  2.71it/s]
# minbatch process in DataLoader:   6%|▋         | 59/938 [00:21<05:23,  2.72it/s]
# minbatch process in DataLoader:   6%|▋         | 60/938 [00:22<05:23,  2.71it/s]
# minbatch process in DataLoader:   7%|▋         | 61/938 [00:22<05:22,  2.72it/s]
# minbatch process in DataLoader:   7%|▋         | 62/938 [00:22<05:22,  2.72it/s]
# minbatch process in DataLoader:   7%|▋         | 63/938 [00:23<05:22,  2.72it/s]
# minbatch process in DataLoader:   7%|▋         | 64/938 [00:23<05:21,  2.72it/s]
# minbatch process in DataLoader:   7%|▋         | 65/938 [00:23<05:21,  2.71it/s]
# minbatch process in DataLoader:   7%|▋         | 66/938 [00:24<05:21,  2.72it/s]
# minbatch process in DataLoader:   7%|▋         | 67/938 [00:24<05:20,  2.72it/s]
# minbatch process in DataLoader:   7%|▋         | 68/938 [00:25<05:20,  2.72it/s]
# minbatch process in DataLoader:   7%|▋         | 69/938 [00:25<05:20,  2.71it/s]
# minbatch process in DataLoader:   7%|▋         | 70/938 [00:25<05:20,  2.71it/s]
# minbatch process in DataLoader:   8%|▊         | 71/938 [00:26<05:23,  2.68it/s]
# minbatch process in DataLoader:   8%|▊         | 72/938 [00:26<05:26,  2.65it/s]
# minbatch process in DataLoader:   8%|▊         | 73/938 [00:26<05:27,  2.64it/s]
# minbatch process in DataLoader:   8%|▊         | 74/938 [00:27<05:26,  2.65it/s]
# minbatch process in DataLoader:   8%|▊         | 75/938 [00:27<05:27,  2.64it/s]
# minbatch process in DataLoader:   8%|▊         | 76/938 [00:28<05:24,  2.66it/s]
# minbatch process in DataLoader:   8%|▊         | 77/938 [00:28<05:21,  2.68it/s]
# minbatch process in DataLoader:   8%|▊         | 78/938 [00:28<05:19,  2.69it/s]
# minbatch process in DataLoader:   8%|▊         | 79/938 [00:29<05:18,  2.69it/s]
# minbatch process in DataLoader:   9%|▊         | 80/938 [00:29<05:21,  2.67it/s]
# minbatch process in DataLoader:   9%|▊         | 81/938 [00:29<05:19,  2.68it/s]
# minbatch process in DataLoader:   9%|▊         | 82/938 [00:30<05:17,  2.69it/s]
# minbatch process in DataLoader:   9%|▉         | 83/938 [00:30<05:21,  2.66it/s]
# minbatch process in DataLoader:   9%|▉         | 84/938 [00:31<05:19,  2.67it/s]
# minbatch process in DataLoader:   9%|▉         | 85/938 [00:31<05:22,  2.64it/s]
# minbatch process in DataLoader:   9%|▉         | 86/938 [00:31<05:24,  2.62it/s]
# minbatch process in DataLoader:   9%|▉         | 87/938 [00:32<05:21,  2.64it/s]
# minbatch process in DataLoader:   9%|▉         | 88/938 [00:32<05:22,  2.63it/s]
# minbatch process in DataLoader:   9%|▉         | 89/938 [00:32<05:24,  2.62it/s]
# minbatch process in DataLoader:  10%|▉         | 90/938 [00:33<05:23,  2.62it/s]
# minbatch process in DataLoader:  10%|▉         | 91/938 [00:33<05:26,  2.59it/s]
# minbatch process in DataLoader:  10%|▉         | 92/938 [00:34<05:26,  2.59it/s]
# minbatch process in DataLoader:  10%|▉         | 93/938 [00:34<05:27,  2.58it/s]
# minbatch process in DataLoader:  10%|█         | 94/938 [00:34<05:26,  2.59it/s]
# minbatch process in DataLoader:  10%|█         | 95/938 [00:35<05:26,  2.58it/s]
# minbatch process in DataLoader:  10%|█         | 96/938 [00:35<05:26,  2.58it/s]
# minbatch process in DataLoader:  10%|█         | 97/938 [00:36<05:25,  2.58it/s]
# minbatch process in DataLoader:  10%|█         | 98/938 [00:36<05:25,  2.58it/s]
# minbatch process in DataLoader:  11%|█         | 99/938 [00:36<05:25,  2.58it/s]
# minbatch process in DataLoader:  11%|█         | 100/938 [00:37<05:25,  2.58it/s]
# minbatch process in DataLoader:  11%|█         | 101/938 [00:37<05:24,  2.58it/s]
# minbatch process in DataLoader:  11%|█         | 102/938 [00:37<05:24,  2.58it/s]
# minbatch process in DataLoader:  11%|█         | 103/938 [00:38<05:24,  2.58it/s]
# minbatch process in DataLoader:  11%|█         | 104/938 [00:38<05:23,  2.58it/s]
# minbatch process in DataLoader:  11%|█         | 105/938 [00:39<05:23,  2.58it/s]
# minbatch process in DataLoader:  11%|█▏        | 106/938 [00:39<05:22,  2.58it/s]
# minbatch process in DataLoader:  11%|█▏        | 107/938 [00:39<05:21,  2.58it/s]
# minbatch process in DataLoader:  12%|█▏        | 108/938 [00:40<05:21,  2.59it/s]
# minbatch process in DataLoader:  12%|█▏        | 109/938 [00:40<05:21,  2.58it/s]
# minbatch process in DataLoader:  12%|█▏        | 110/938 [00:41<05:20,  2.58it/s]
# minbatch process in DataLoader:  12%|█▏        | 111/938 [00:41<05:20,  2.58it/s]
# minbatch process in DataLoader:  12%|█▏        | 112/938 [00:41<05:20,  2.58it/s]
# minbatch process in DataLoader:  12%|█▏        | 113/938 [00:42<05:16,  2.61it/s]
# minbatch process in DataLoader:  12%|█▏        | 114/938 [00:42<05:16,  2.61it/s]
# minbatch process in DataLoader:  12%|█▏        | 115/938 [00:43<05:15,  2.60it/s]
# minbatch process in DataLoader:  12%|█▏        | 116/938 [00:43<05:16,  2.60it/s]
# minbatch process in DataLoader:  12%|█▏        | 117/938 [00:43<05:16,  2.59it/s]
# minbatch process in DataLoader:  13%|█▎        | 118/938 [00:44<05:16,  2.59it/s]
# minbatch process in DataLoader:  13%|█▎        | 119/938 [00:44<05:15,  2.59it/s]
# minbatch process in DataLoader:  13%|█▎        | 120/938 [00:44<05:16,  2.58it/s]
# minbatch process in DataLoader:  13%|█▎        | 121/938 [00:45<05:11,  2.62it/s]
# minbatch process in DataLoader:  13%|█▎        | 122/938 [00:45<05:07,  2.65it/s]
# minbatch process in DataLoader:  13%|█▎        | 123/938 [00:46<05:05,  2.67it/s]
# minbatch process in DataLoader:  13%|█▎        | 124/938 [00:46<05:03,  2.68it/s]
# minbatch process in DataLoader:  13%|█▎        | 125/938 [00:46<05:01,  2.70it/s]
# minbatch process in DataLoader:  13%|█▎        | 126/938 [00:47<05:00,  2.71it/s]
# minbatch process in DataLoader:  14%|█▎        | 127/938 [00:47<04:59,  2.71it/s]
# minbatch process in DataLoader:  14%|█▎        | 128/938 [00:47<04:58,  2.72it/s]
# minbatch process in DataLoader:  14%|█▍        | 129/938 [00:48<04:57,  2.72it/s]
# minbatch process in DataLoader:  14%|█▍        | 130/938 [00:48<04:57,  2.71it/s]
# minbatch process in DataLoader:  14%|█▍        | 131/938 [00:48<04:56,  2.72it/s]
# minbatch process in DataLoader:  14%|█▍        | 132/938 [00:49<04:56,  2.72it/s]
# minbatch process in DataLoader:  14%|█▍        | 133/938 [00:49<04:56,  2.72it/s]
# minbatch process in DataLoader:  14%|█▍        | 134/938 [00:50<04:55,  2.72it/s]
# minbatch process in DataLoader:  14%|█▍        | 135/938 [00:50<04:55,  2.72it/s]
# minbatch process in DataLoader:  14%|█▍        | 136/938 [00:50<04:54,  2.72it/s]
# minbatch process in DataLoader:  15%|█▍        | 137/938 [00:51<04:54,  2.72it/s]
# minbatch process in DataLoader:  15%|█▍        | 138/938 [00:51<04:53,  2.72it/s]
# minbatch process in DataLoader:  15%|█▍        | 139/938 [00:51<04:53,  2.72it/s]
# minbatch process in DataLoader:  15%|█▍        | 140/938 [00:52<04:53,  2.72it/s]
# minbatch process in DataLoader:  15%|█▌        | 141/938 [00:52<04:53,  2.72it/s]
# minbatch process in DataLoader:  15%|█▌        | 142/938 [00:53<04:52,  2.72it/s]
# minbatch process in DataLoader:  15%|█▌        | 143/938 [00:53<04:52,  2.72it/s]
# minbatch process in DataLoader:  15%|█▌        | 144/938 [00:53<04:51,  2.72it/s]
# minbatch process in DataLoader:  15%|█▌        | 145/938 [00:54<04:51,  2.72it/s]
# minbatch process in DataLoader:  16%|█▌        | 146/938 [00:54<04:51,  2.72it/s]
# minbatch process in DataLoader:  16%|█▌        | 147/938 [00:54<04:50,  2.72it/s]
# minbatch process in DataLoader:  16%|█▌        | 148/938 [00:55<04:50,  2.72it/s]
# minbatch process in DataLoader:  16%|█▌        | 149/938 [00:55<04:50,  2.72it/s]
# minbatch process in DataLoader:  16%|█▌        | 150/938 [00:55<04:49,  2.72it/s]
# minbatch process in DataLoader:  16%|█▌        | 151/938 [00:56<04:49,  2.72it/s]
# minbatch process in DataLoader:  16%|█▌        | 152/938 [00:56<04:48,  2.72it/s]
# minbatch process in DataLoader:  16%|█▋        | 153/938 [00:57<04:48,  2.72it/s]
# minbatch process in DataLoader:  16%|█▋        | 154/938 [00:57<04:48,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 155/938 [00:57<04:47,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 156/938 [00:58<04:47,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 157/938 [00:58<04:46,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 158/938 [00:58<04:46,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 159/938 [00:59<04:45,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 160/938 [00:59<04:45,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 161/938 [01:00<04:45,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 162/938 [01:00<04:45,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 163/938 [01:00<04:44,  2.72it/s]
# minbatch process in DataLoader:  17%|█▋        | 164/938 [01:01<04:44,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 165/938 [01:01<04:44,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 166/938 [01:01<04:43,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 167/938 [01:02<04:43,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 168/938 [01:02<04:43,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 169/938 [01:02<04:42,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 170/938 [01:03<04:42,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 171/938 [01:03<04:42,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 172/938 [01:04<04:41,  2.72it/s]
# minbatch process in DataLoader:  18%|█▊        | 173/938 [01:04<04:41,  2.72it/s]
# minbatch process in DataLoader:  19%|█▊        | 174/938 [01:04<04:40,  2.72it/s]
# minbatch process in DataLoader:  19%|█▊        | 175/938 [01:05<04:40,  2.72it/s]
# minbatch process in DataLoader:  19%|█▉        | 176/938 [01:05<04:40,  2.72it/s]
# minbatch process in DataLoader:  19%|█▉        | 177/938 [01:05<04:39,  2.72it/s]
# minbatch process in DataLoader:  19%|█▉        | 178/938 [01:06<04:39,  2.72it/s]
# minbatch process in DataLoader:  19%|█▉        | 179/938 [01:06<04:38,  2.72it/s]
# minbatch process in DataLoader:  52%|█████▏    | 486/938 [02:59<02:46,  2.72it/s]
# minbatch process in DataLoader:  52%|█████▏    | 487/938 [02:59<02:45,  2.72it/s]
# minbatch process in DataLoader:  52%|█████▏    | 488/938 [03:00<02:45,  2.72it/s]
# minbatch process in DataLoader:  52%|█████▏    | 489/938 [03:00<02:44,  2.72it/s]
# minbatch process in DataLoader:  52%|█████▏    | 490/938 [03:00<02:44,  2.72it/s]
# minbatch process in DataLoader:  52%|█████▏    | 491/938 [03:01<02:44,  2.72it/s]
# minbatch process in DataLoader:  52%|█████▏    | 492/938 [03:01<02:43,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 493/938 [03:02<02:43,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 494/938 [03:02<02:43,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 495/938 [03:02<02:42,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 496/938 [03:03<02:42,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 497/938 [03:03<02:42,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 498/938 [03:03<02:41,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 499/938 [03:04<02:41,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 500/938 [03:04<02:41,  2.72it/s]
# minbatch process in DataLoader:  53%|█████▎    | 501/938 [03:05<02:40,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▎    | 502/938 [03:05<02:40,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▎    | 503/938 [03:05<02:40,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▎    | 504/938 [03:06<02:39,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▍    | 505/938 [03:06<02:39,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▍    | 506/938 [03:06<02:38,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▍    | 507/938 [03:07<02:38,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▍    | 508/938 [03:07<02:38,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▍    | 509/938 [03:07<02:37,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▍    | 510/938 [03:08<02:37,  2.72it/s]
# minbatch process in DataLoader:  54%|█████▍    | 511/938 [03:08<02:36,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▍    | 512/938 [03:09<02:36,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▍    | 513/938 [03:09<02:36,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▍    | 514/938 [03:09<02:35,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▍    | 515/938 [03:10<02:35,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▌    | 516/938 [03:10<02:35,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▌    | 517/938 [03:10<02:34,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▌    | 518/938 [03:11<02:34,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▌    | 519/938 [03:11<02:33,  2.72it/s]
# minbatch process in DataLoader:  55%|█████▌    | 520/938 [03:12<02:33,  2.72it/s]
# minbatch process in DataLoader:  56%|█████▌    | 521/938 [03:12<02:33,  2.72it/s]
# ...
#
# minbatch process in DataLoader:  29%|██▉       | 272/938 [01:40<04:04,  2.72it/s]
#
# minbatch process in DataLoader:  29%|██▉       | 273/938 [01:40<04:04,  2.72it/s]
#
# minbatch process in DataLoader:  29%|██▉       | 274/938 [01:40<04:04,  2.72it/s]
#
# minbatch process in DataLoader:  29%|██▉       | 275/938 [01:41<04:03,  2.72it/s]
#
# minbatch process in DataLoader:  29%|██▉       | 276/938 [01:41<04:03,  2.72it/s]
#
# minbatch process in DataLoader:  30%|██▉       | 277/938 [01:41<04:02,  2.72it/s]
#
# minbatch process in DataLoader:  30%|██▉       | 278/938 [01:42<04:02,  2.72it/s]
#
# minbatch process in DataLoader:  30%|██▉       | 279/938 [01:42<04:02,  2.72it/s]
#
# minbatch process in DataLoader:  30%|██▉       | 280/938 [01:42<04:01,  2.72it/s]
#
# minbatch process in DataLoader:  30%|██▉       | 281/938 [01:43<04:01,  2.72it/s]
#
# minbatch process in DataLoader:  30%|███       | 282/938 [01:43<04:01,  2.72it/s]
#
# minbatch process in DataLoader:  30%|███       | 283/938 [01:44<04:00,  2.72it/s]
#
# minbatch process in DataLoader:  30%|███       | 284/938 [01:44<04:00,  2.72it/s]
#
# minbatch process in DataLoader:  30%|███       | 285/938 [01:44<04:00,  2.72it/s]
#
# minbatch process in DataLoader:  30%|███       | 286/938 [01:45<03:59,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███       | 287/938 [01:45<03:59,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███       | 288/938 [01:45<03:58,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███       | 289/938 [01:46<03:58,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███       | 290/938 [01:46<03:58,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███       | 291/938 [01:47<03:57,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███       | 292/938 [01:47<03:57,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███       | 293/938 [01:47<03:57,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███▏      | 294/938 [01:48<03:56,  2.72it/s]
#
# minbatch process in DataLoader:  31%|███▏      | 295/938 [01:48<03:56,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 296/938 [01:48<03:55,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 297/938 [01:49<03:55,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 298/938 [01:49<03:55,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 299/938 [01:49<03:54,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 300/938 [01:50<03:54,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 301/938 [01:50<03:54,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 302/938 [01:51<03:53,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 303/938 [01:51<03:53,  2.72it/s]
#
# minbatch process in DataLoader:  32%|███▏      | 304/938 [01:51<03:53,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 305/938 [01:52<03:52,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 306/938 [01:52<03:52,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 307/938 [01:52<03:52,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 308/938 [01:53<03:51,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 309/938 [01:53<03:51,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 310/938 [01:53<03:50,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 311/938 [01:54<03:50,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 312/938 [01:54<03:49,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 313/938 [01:55<03:49,  2.72it/s]
#
# minbatch process in DataLoader:  33%|███▎      | 314/938 [01:55<03:49,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▎      | 315/938 [01:55<03:48,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▎      | 316/938 [01:56<03:48,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▍      | 317/938 [01:56<03:48,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▍      | 318/938 [01:56<03:47,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▍      | 319/938 [01:57<03:47,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▍      | 320/938 [01:57<03:47,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▍      | 321/938 [01:58<03:46,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▍      | 322/938 [01:58<03:46,  2.72it/s]
#
# minbatch process in DataLoader:  34%|███▍      | 323/938 [01:58<03:45,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▍      | 324/938 [01:59<03:45,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▍      | 325/938 [01:59<03:45,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▍      | 326/938 [01:59<03:44,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▍      | 327/938 [02:00<03:44,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▍      | 328/938 [02:00<03:44,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▌      | 329/938 [02:00<03:43,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▌      | 330/938 [02:01<03:43,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▌      | 331/938 [02:01<03:42,  2.72it/s]
#
# minbatch process in DataLoader:  35%|███▌      | 332/938 [02:02<03:42,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 333/938 [02:02<03:42,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 334/938 [02:02<03:41,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 335/938 [02:03<03:41,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 336/938 [02:03<03:41,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 337/938 [02:03<03:40,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 338/938 [02:04<03:40,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 339/938 [02:04<03:39,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▌      | 340/938 [02:05<03:39,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▋      | 341/938 [02:05<03:39,  2.72it/s]
#
# minbatch process in DataLoader:  36%|███▋      | 342/938 [02:05<03:38,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 343/938 [02:06<03:38,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 344/938 [02:06<03:38,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 345/938 [02:06<03:37,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 346/938 [02:07<03:37,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 347/938 [02:07<03:37,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 348/938 [02:07<03:36,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 349/938 [02:08<03:36,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 350/938 [02:08<03:35,  2.72it/s]
#
# minbatch process in DataLoader:  37%|███▋      | 351/938 [02:09<03:35,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 352/938 [02:09<03:35,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 353/938 [02:09<03:34,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 354/938 [02:10<03:34,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 355/938 [02:10<03:34,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 356/938 [02:10<03:33,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 357/938 [02:11<03:33,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 358/938 [02:11<03:33,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 359/938 [02:11<03:32,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 360/938 [02:12<03:32,  2.72it/s]
#
# minbatch process in DataLoader:  38%|███▊      | 361/938 [02:12<03:32,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▊      | 362/938 [02:13<03:31,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▊      | 363/938 [02:13<03:31,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▉      | 364/938 [02:13<03:31,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▉      | 365/938 [02:14<03:30,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▉      | 366/938 [02:14<03:30,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▉      | 367/938 [02:14<03:29,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▉      | 368/938 [02:15<03:29,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▉      | 369/938 [02:15<03:28,  2.72it/s]
#
# minbatch process in DataLoader:  39%|███▉      | 370/938 [02:16<03:28,  2.72it/s]
#
# minbatch process in DataLoader:  40%|███▉      | 371/938 [02:16<03:28,  2.72it/s]
#
# minbatch process in DataLoader:  40%|███▉      | 372/938 [02:16<03:28,  2.72it/s]
#
# minbatch process in DataLoader:  40%|███▉      | 373/938 [02:17<03:27,  2.72it/s]
#
# minbatch process in DataLoader:  40%|███▉      | 374/938 [02:17<03:27,  2.72it/s]
#
# minbatch process in DataLoader:  40%|███▉      | 375/938 [02:17<03:26,  2.72it/s]
#
# minbatch process in DataLoader:  40%|████      | 376/938 [02:18<03:26,  2.72it/s]
#
# minbatch process in DataLoader:  40%|████      | 377/938 [02:18<03:25,  2.72it/s]
#
# minbatch process in DataLoader:  40%|████      | 378/938 [02:18<03:25,  2.72it/s]
#
# minbatch process in DataLoader:  40%|████      | 379/938 [02:19<03:25,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████      | 380/938 [02:19<03:25,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████      | 381/938 [02:20<03:24,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████      | 382/938 [02:20<03:24,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████      | 383/938 [02:20<03:23,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████      | 384/938 [02:21<03:23,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████      | 385/938 [02:21<03:23,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████      | 386/938 [02:21<03:23,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████▏     | 387/938 [02:22<03:22,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████▏     | 388/938 [02:22<03:22,  2.72it/s]
#
# minbatch process in DataLoader:  41%|████▏     | 389/938 [02:23<03:21,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 390/938 [02:23<03:21,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 391/938 [02:23<03:21,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 392/938 [02:24<03:20,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 393/938 [02:24<03:20,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 394/938 [02:24<03:20,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 395/938 [02:25<03:19,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 396/938 [02:25<03:19,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 397/938 [02:25<03:19,  2.72it/s]
#
# minbatch process in DataLoader:  42%|████▏     | 398/938 [02:26<03:18,  2.72it/s]
#
#
# minbatch process in DataLoader:  46%|████▌     | 432/938 [02:38<03:06,  2.71it/s]
#
# minbatch process in DataLoader:  46%|████▌     | 433/938 [02:39<03:05,  2.72it/s]
#
# minbatch process in DataLoader:  46%|████▋     | 434/938 [02:39<03:05,  2.72it/s]
#
# minbatch process in DataLoader:  46%|████▋     | 435/938 [02:39<03:05,  2.72it/s]
#
# minbatch process in DataLoader:  46%|████▋     | 436/938 [02:40<03:04,  2.72it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 437/938 [02:40<03:04,  2.72it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 438/938 [02:41<03:04,  2.72it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 439/938 [02:41<03:03,  2.72it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 440/938 [02:41<03:03,  2.72it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 441/938 [02:42<03:03,  2.72it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 442/938 [02:42<03:02,  2.71it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 443/938 [02:42<03:02,  2.71it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 444/938 [02:43<03:01,  2.72it/s]
#
# minbatch process in DataLoader:  47%|████▋     | 445/938 [02:43<03:01,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 446/938 [02:44<03:01,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 447/938 [02:44<03:00,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 448/938 [02:44<03:00,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 449/938 [02:45<02:59,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 450/938 [02:45<02:59,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 451/938 [02:45<02:59,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 452/938 [02:46<02:58,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 453/938 [02:46<02:58,  2.72it/s]
#
# minbatch process in DataLoader:  48%|████▊     | 454/938 [02:46<02:57,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▊     | 455/938 [02:47<02:57,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▊     | 456/938 [02:47<02:57,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▊     | 457/938 [02:48<02:56,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▉     | 458/938 [02:48<02:56,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▉     | 459/938 [02:48<02:55,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▉     | 460/938 [02:49<02:55,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▉     | 461/938 [02:49<02:55,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▉     | 462/938 [02:49<02:54,  2.72it/s]
#
# minbatch process in DataLoader:  49%|████▉     | 463/938 [02:50<02:54,  2.72it/s]
